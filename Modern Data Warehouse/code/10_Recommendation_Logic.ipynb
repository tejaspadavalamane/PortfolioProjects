# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, ce268239-1cf4-4f3c-833c-0f6ee500c095, 3, Finished, Available)

# %%
mssparkutils.fs.mount("abfss://Tejas_MDW_FinalProj@onelake.dfs.fabric.microsoft.com/TMDW_FinalProj.Lakehouse/Files","/Files")
# Out:
# StatementMeta(, ce268239-1cf4-4f3c-833c-0f6ee500c095, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 2c8c7a05-7add-46a7-9139-8159dc89adf4)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, ce268239-1cf4-4f3c-833c-0f6ee500c095, 5, Finished, Available)
# '/synfs/notebook/ce268239-1cf4-4f3c-833c-0f6ee500c095/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/C/")
# Out:
# StatementMeta(, ce268239-1cf4-4f3c-833c-0f6ee500c095, 6, Finished, Available)

# %%
check_files
# Out:
# StatementMeta(, ce268239-1cf4-4f3c-833c-0f6ee500c095, 7, Finished, Available)
# []

# %%
if check_files:
    mssparkutils.notebook.run("bnze_Sales")
    mssparkutils.notebook.run("G_Customer")
    mssparkutils.notebook.run("G_Date")
    mssparkutils.notebook.run("G_Product")
    mssparkutils.notebook.run("Gld_ShipMode")
    mssparkutils.notebook.run("G_OrderPriority")
    mssparkutils.notebook.run("Order_Return_G")
    mssparkutils.notebook.run("G_FactSale")
    mssparkutils.notebook.run("A_Files")
# Out:
# StatementMeta(, ce268239-1cf4-4f3c-833c-0f6ee500c095, 13, Finished, Available)
