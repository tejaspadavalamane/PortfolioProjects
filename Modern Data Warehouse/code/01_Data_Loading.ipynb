# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 90e3a10d-6688-4c41-b211-e6e37ba15346, 3, Finished, Available)

# %%
mssparkutils.fs.mount("abfss://Tejas_MDW_FinalProj@onelake.dfs.fabric.microsoft.com/TMDW_FinalProj.Lakehouse/Files","/Files")
# Out:
# StatementMeta(, 90e3a10d-6688-4c41-b211-e6e37ba15346, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, fbd2d147-13bc-41ed-9205-e1edfcf4effd)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 90e3a10d-6688-4c41-b211-e6e37ba15346, 6, Finished, Available)
# '/synfs/notebook/90e3a10d-6688-4c41-b211-e6e37ba15346/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/C/")
# Out:
# StatementMeta(, 90e3a10d-6688-4c41-b211-e6e37ba15346, 8, Finished, Available)

# %%
for file in check_files:
    if file.path:
        mssparkutils.fs.mv(file.path,f"file://{mssparkutils.fs.getMountPath('/Files')}/A/")
# Out:
# StatementMeta(, 90e3a10d-6688-4c41-b211-e6e37ba15346, 10, Finished, Available)
